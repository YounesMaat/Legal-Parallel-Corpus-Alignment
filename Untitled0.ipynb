# %% [markdown]
# import re
#
# a = open("/content/drive/MyDrive/TRY/AR.txt","r").read()
# f = open("/content/drive/MyDrive/TRY/FR.txt","r").read()
# s = open("/content/drive/MyDrive/TRY/TRY.txt","w+")
# ar = re.split(r'(\n\s*الفصل\s*.{,10}\n)',a)
# ar_2 = re.split(r'(\\\\\\\\\\n\s*الفصل\s*.{,10}\n)',a)
# fr = re.split(r'(\n\s*Article\s+.{,10}\n)',f)
#
# print (len(fr), len(ar_2))
#
# for a,b in zip(ar,fr):
#   s.write(
#       f"""
#       ************************Arabic***********************
#       {a}
#       ************************French************************
#       {b}
#   """)

# %%
import os, re

l = os.listdir("C:\\Users\\YM\\Desktop\\Nouveau dossier\\DATA\\MAROC/")

for dir in l:

  f_ = os.listdir(f"C:\\Users\\YM\\Desktop\\Nouveau dossier\\DATA\\MAROC/{dir}")
  print(f_)
  input('>>')
  for f in f_:
      #c_f = open (f"/content/drive/MyDrive/DATA/MAROC/{dir}/{f}",'r+').read()
      if "FR" in f:
        pass
        #print (f)
       # c_f = re.sub("-\s*\d{1,3}\s*-\s*\n"," ",c_f)



      else:
        pass
      print(f)
      #c_f = re.sub(r'\n\s*\n','\n', c_f)


      #os.remove(f"/content/drive/MyDrive/DATA/MAROC/{dir}/{f}")
      #open (f"/content/drive/MyDrive/DATA/MAROC/{dir}/++{f}",'w+').write(c_f)

# %%
import os, re, openai

class Legal_align ():
  def __init__(self):
    dirs = os.listdir("C:\\Users\\YM\\Desktop\\Nouveau dossier\\DATA\\MAROC")

    for dir in dirs:
      print (dir)
      srt_dir = sorted(os.listdir(f"C:\\Users\\YM\\Desktop\\Nouveau dossier\\DATA\\MAROC\\{dir}"))
      
      n = 0
      for File in srt_dir:

        
        n = n+1
        
        try:
          if "AR." in File:
            
            t_a = File
            
            Text_A = open(f"C:\\Users\\YM\\Desktop\\Nouveau dossier\\DATA\\MAROC\\{dir}\\{File}", "r",encoding="utf-8").read()
            
            
          if "FR." in File:
            Text_B = open(f"C:\\Users\\YM\\Desktop\\Nouveau dossier\\DATA\\MAROC\\{dir}\\{File}", "r",encoding="utf-8").read()
            
            t_b = File
          
          

          if n % 2 == 0:
            print (t_a, "***", t_b)
            self.process (Text_A , Text_B)
            
        except:

          print("raise errono")


  def pre_process (self):
    pass
    # empty lines

  def process (self, src_txt, trg_txt):
    ptrn = [r'(\n\s*الفصل\s*.{,10}\n)',r'(\n\s*المادة\s*.{,10}\n)',r'(\n\s*الفصل\s*.{,10}\n|\n\s*المادة\s*.{,10}\n)']
    #split the text by the article
    src = re.split(ptrn[0], src_txt)
    trg = re.split(r'(\n\s*Article\s+.{,10}\n)', trg_txt)

    if len(trg) == len(re.split(ptrn[2], src_txt)):
      print ("call")
      src = re.split(ptrn[2], src_txt)
    elif len(src) < len(re.split(ptrn[1], src_txt)) :
      src = re.split(ptrn[1], src_txt)
      pass
    
    print (len(src) , len(trg))
    for n in range(len(src)):
      if n % 2 != 0:
        #print (src[n],trg[n])
        pass


    #compare if the two are equi

    a = 0
    b = 0
    src_d = open("src.txt", "a+", encoding="utf-8")
    trg_d = open("trg.txt", "a+", encoding="utf-8")
    for s,t in zip(src,trg):

      if len(s.split("\n")) == len(t.split("\n")):
        pass
        a = a+1

        #print (len(s.split("\n")), len(t.split("\n")),": Equal")
        # if equi --> write to add to the files
        #src_d.write(s)
        #trg_d.write(t)
        
      else:
        b = b+1
        pass
       # print (len(s.split("\n")), len(t.split("\n")), ": Not Equal")
        if len(s.split("\n")) < 6:
          
          self.Align(t,s)
          input(">>")
          
    
        # give it to align to handle it and then add it ...
    
    print (f"equal {a} : not eq {b}")
    print ("*"*30)
    
  def Align (self, Text_A, Text_B):
    
    print (f"align is called:\n{Text_A} \n ** \n {Text_B}")
    openai.api_key = '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'

    instructions = """
    - Make a sentence to sentence alignment
    - Look at the source text and target text to set the equivalence
    - Don't stop unless you aligned all the sentences
    - If the equivalent is missed, write N/A
    """

    #response
    response = openai.ChatCompletion.create(
      model = "gpt-3.5-turbo",
      temperature = 1.1,
      max_tokens = 1000,
      messages = [
        {"role": "system", "content": f"you are an assistant that takes a text in two languages and align them in a table, continue generation untill the text is done "},
        {"role": "assistant", "content": f"give me  a text in two languages and I will give you an table of aligned complete sentences"},
        {"role": "user", "content": f"align the text into a table of French and Arabic. \n\n French Text:\n{Text_A}\n\n Arabic Text:\n{Text_B}"},
        {"role": "assistant", "content": f"I will align the text in a table of French - Arabic following the instructions: {instructions}"}
      ]
    )
    print (response['choices'][0]['message']['content'])

    #Add check here and while ...
    #return response['choices'][0]['message']['content']


Legal_align()
# Out:
# التنظيم القضائي والمهن القضائية
# ++JUR_Commerce_MAR_AR.pdf.txt *** ++JUR_Commerce_MAR_FR.pdf.txt
# 51 51
# align is called:
# Il est créé en vertu de la présente loi des tribunaux de commerce et des cours d'appel de commerce.
# Leur nombre, leurs sièges dans les régions et leur ressort sont fixés par décret2.
# TITRE II : COMPOSITION ET ORGANISATION DES TRIBUNAUX DE COMMERCE ET DES COURS D'APPEL DE COMMERCE
#  **
#  تحدث بمقتضى هذا القانون محاكم تجارية و محاكم استئناف   تجارية.
# يحدث بمرسوم عدد هذه المحاكم و مقارها بالجهات و دوائر اختصاصها.
# القسم الثاني
# تكوين المحاكم التجارية
# و محاكم الاستئناف التجارية و تنظيمها
# | French Text | Arabic Text |
# | --- | --- |
# | Il est créé en vertu de la présente loi des tribunaux de commerce et des cours d'appel de commerce. | تحدث بمقتضى هذا القانون محاكم تجارية و محاكم استئناف   تجارية. |
# ...

# %%
import re

# read
a = open("MAROC\المادة الجنائية\++DR_LUTTE CONTRE LE_MAR_AR.pdf.txt","r",encoding="utf-8").read()
f = open("MAROC\المادة الجنائية\++DR_LUTTE CONTRE LE_MAR_FR.pdf.txt","r",encoding="utf-8").read()
#s = open("/content/drive/MyDrive/TRY/TRY.txt","w+")

ptrn = [r'(\n\s*الفصل\s*.{,10}\n)',r'(\n\s*المادة\s*.{,10}\n)',r'(\n\s*الفصل\s*.{,10}\n|\n\s*المادة\s*.{,10}\n)']

#a_ = open("/content/drive/MyDrive/TRY/en-al.txt","w+")
#f_ = open("/content/drive/MyDrive/TRY/f-al.txt","w+")

ar = re.split(ptrn[0], a)
fr = re.split(r'(\n\s*Article\s+.{,10}\n)',f)



if len(fr) == len(re.split(ptrn[2], a)):
   ar = re.split(ptrn[2], a)
elif len(ar) < len(re.split(ptrn[1], a)):
      ar = re.split(ptrn[1], a)



a = re.sub("\n\s*\n", "\n", a)
open("MAROC\\fil.txt","w+",encoding="utf-8").write(a)
print (len(fr), len(ar))
c = 0
d = 0

for a in range(len(ar)):
  if a % 2 != 0:

    print (ar[a], fr[a])
    if "." in ar[a]:
      print (ar[a])
      pass
for a,b in zip(ar,fr):



  if len(a.split("\n")) == len(b.split("\n")):
    c = c+1

  if len(a.split("\n")) != len(b.split("\n")):
    d=d+1

    print (a, b)
    #input("******************************************")

print (f"test equiv : equal {c} -- not equal {d}")
# Out:
# 95 95
#
# المادة 1
#
# Article premier
#
#
# الفصل 1 - 574
#
# Article 574-12
#
#
# الفصل 2 - 574
#
# Article 574-24
#
#
# الفصل 3 - 574
#
# Article 574-35
#
#
# الفصل 4 - 574
#
# Article 574-4
#
#
# الفصل 5 - 574
#
# Article 574-56
#
#
# الفصل 6 - 574
#
#  Article 574-6
#
#
# الفصل 7 - 574
#
# Article 574-7
#
#
# المادة 2
#
# Article deux
#
#
# المادة 1
#
# Article premier7
#
#
# المادة 2
#
#  Article 29
#
#
# المادة 3
#
# Article 310
#
#
# المادة 4
#
#  Article 4
#
#
# المادة 5
#
# Article 511
#
#
# المادة 6
#
# Article 612
#
#
# المادة 7
#
#  Article 713
#
#
# المادة 8
#
# Article 814
#
#
# المادة 9
#
# Article 915
#
#
# المادة 10
#
# Article 10
#
#
# المادة 11
#
# Article 11
#
#
# المادة 12
#
# Article 1216
#
#
# المادة 13
#
# Article 1317
#
#
# المادة 14
#
# Article 14
#
#
# المادة 15
#
# Article 1521
#
#
# المادة 16
#
# Article 16
#
#
# المادة 17
#
# Article 17
#
#
# المادة 18
#
# Article 1823
#
#
# المادة 19
#
# Article 19
#
#
# المادة 20
#
# Article 20
#
#
# المادة 21
#
# ...

# %%
import re

a = open("/content/drive/MyDrive/TRY/DATA/DR_Penal_AR.txt","r").read()
f = open("/content/drive/MyDrive/TRY/DATA/DR_Penal_FR.txt","r").read()
#s = open("/content/drive/MyDrive/TRY/TRY.txt","w+")

a = re.sub(r'\n\s*\n','\n',a)
f = re.sub(r'\n\s*\n','\n',f)

ar = re.split(r'(\n\s*الفصل\s*.{,10}\n)',a)
fr = re.split(r'(\n\s*Article\s+.{,10}\n)',f)

print (len(fr), len(ar))

eq_l = 0
uneq_l = 0
#articles equivalence مطابقة الفصول
for a in range(len(ar)):
  if a%2 != 0:
    print(ar[a], fr[a])
#length of lines ..
  else:
    print(len(ar[a].split("\n")), len(fr[a].split("\n")))
    if len(ar[a].split("\n")) == len(fr[a].split("\n")):
      eq_l = eq_l + 1
      print ("equal : ", eq_l)
    else:
      uneq_l = uneq_l + 1
      print ("unequal : ", uneq_l)

  #print uneq
      print (ar[a],"\n",fr[a])
      input(">>")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 import re
# ----> 3 a = open("/content/drive/MyDrive/TRY/DATA/DR_Penal_AR.txt","r").read()
#       4 f = open("/content/drive/MyDrive/TRY/DATA/DR_Penal_FR.txt","r").read()
#       5 #s = open("/content/drive/MyDrive/TRY/TRY.txt","w+")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget ftp://ftp.mokk.bme.hu/Hunglish/src/hunalign/latest/hunalign-1.2-windows.zip
# Out:
# --2023-06-06 23:49:36--  https://github.com/rsennrich/Bleualign.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-06-06 23:49:36 ERROR 404: Not Found.

# %%
import re

f = open("/content/drive/MyDrive/TRY/EN.txt","r").read()
#en = open("/content/drive/MyDrive/TRY/TR.txt","r").read()


f_n = open("/content/drive/MyDrive/TRY/f-al.txt","a+")
en_n = open("/content/drive/MyDrive/TRY/en-al.txt","w+")


articles_f = re.findall("(?:\n\||^\|) (.*) \|[^\n]", f)
articles_en = re.findall("(?:\n\||^\|) .* \| (.*)\|", en)

f_n.write("\n")
f_n.write("\n".join(articles_f))

# %%
import re

a = open("/content/drive/MyDrive/TRY/AR.txt","r").read()
f = open("/content/drive/MyDrive/TRY/FR.txt","r").read()
s = open("/content/drive/MyDrive/TRY/commercial.txt","r+").read()

ar = re.split(r'(\n\s*الفصل\s*.{,10}\n)',a)
fr = re.split(r'(\n\s*Article\s+.{,10}\n)',f)
s = re.sub(r'\n\s*\n','\n',s)
s = re.split(r'(\n\s*المادة\s+.{,10}\n)',s)



print(len(s))

for a,b in zip(ar,fr):
  a = re.sub(r'\n\s*\n','\n',a)
  b = re.sub(r'\n\s*\n','\n',b)
  a_ = re.sub(r'\n\s*\n','\n',a).split('\n')
  b_ = re.sub(r'\n\s*\n','\n',b).split('\n')
# Out:
# 1135 1135

# %%
import re
s = open("/content/drive/MyDrive/TRY/TRY.txt","r+")

w = re.sub(r'\n\s*\s','\n',s.read())


print(w)

# %% [markdown]
# """for a,b in zip(articles_f, articles_en):
#
#   print(a)
#   #print ("***\n",b)
#  """

# %%
# !pip install openai
# Out:
# ...
#      ---------------------------------------- 0.0/73.6 kB ? eta -:--:--
#      ---------------- ----------------------- 30.7/73.6 kB 1.3 MB/s eta 0:00:01
#      --------------------- ---------------- 41.0/73.6 kB 388.9 kB/s eta 0:00:01
#      -------------------------------------- 73.6/73.6 kB 506.5 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#      ---------------------------------------- 62.6/62.6 kB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/317.2 kB ? eta -:--:--
#      ---- -------------------------------- 41.0/317.2 kB 960.0 kB/s eta 0:00:01
#      ------- ------------------------------- 61.4/317.2 kB 1.1 MB/s eta 0:00:01
#      ------- ------------------------------- 61.4/317.2 kB 1.1 MB/s eta 0:00:01
#      ------- ------------------------------- 61.4/317.2 kB 1.1 MB/s eta 0:00:01
#      ------- ------------------------------- 61.4/317.2 kB 1.1 MB/s eta 0:00:01
# ...

# %%
import openai, re

openai.api_key = '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'


Text_fr = ["""

Il est créé en vertu de la présente loi des tribunaux de commerce et des cours d'appel de commerce.
Leur nombre, leurs sièges dans les régions et leur ressort sont fixés par décret.
TITRE II : COMPOSITION ET ORGANISATION DES TRIBUNAUX DE COMMERCE ET DES COURS D'APPEL DE COMMERCE
"""]

Text_ar = ["""
تحدث بمقتضى هذا القانون محاكم تجارية و محاكم استئناف   تجارية.
يحدث بمرسوم عدد هذه المحاكم و مقارها بالجهات و دوائر اختصاصها.
القسم الثاني
تكوين المحاكم التجارية
و محاكم الاستئناف التجارية و تنظيمها

"""]

instructions = """
- Make a sentence to sentence alignment
- Look at the source text and target text to set the equivalence
- Don't stop unless you aligned all the sentences
- If the equivalent is missed, write N/A
"""

def align (Text_fr,Text_ar):
    response = openai.ChatCompletion.create(
      model = "gpt-3.5-turbo",
      temperature = 1.1,
      max_tokens = 1000,
      messages = [
        {"role": "system", "content": f"you are an assistant that takes a text in two languages and align them in a table, continue generation untill the end of the whole text "},
        {"role": "assistant", "content": f"give me  a text in two languages and I will give you an table of aligned complete sentences"},
        {"role": "user", "content": f"align the text into a table of French and Arabic. Instruction {instructions}:\n\n French Text: \n {Text_fr} \n Arabic Text:\n{Text_ar}"},
        {"role": "assistant", "content": f"I will align the text in a table of French -Arabic following the instructions: {instructions}"}
      ]
    )
    text = (response['choices'][0]['message']['content'])

    print (text)
    
    articles_f = re.findall("(?:\n\||^\|) (.*) \|[^\n]", text)
    articles_en = re.findall("(?:\n\||^\|) .* \| (.*)\|", text)
    del articles_en[0]
    del articles_f[0]
    
    for a in range (len(articles_f)):
        if "N/A" in (articles_f[a] or articles_en[a]) :
          
          align (Text_fr, Text_ar)

        else:
          
          print (f"{articles_f[a]} \n {articles_en[a]}")
          



for a in range(len(Text_fr)):
  text = align(Text_fr[a],Text_ar[a])


  
  #articles_f = re.findall("(?:\n\||^\|) (.*) \|[^\n]", text)
 # articles_en = re.findall("(?:\n\||^\|) .* \| (.*)\|", text)

  for a in range(len(articles_f)):
     #print (f"{articles_f[a]} \n {articles_en[a]}")
     pass
     
  

  print ("--done--")
# Out:
# | French Text | Arabic Text |
# | --- | --- |
# | Il est créé en vertu de la présente loi des tribunaux de commerce et des cours d'appel de commerce. | تحدث بمقتضى هذا القانون محاكم تجارية و محاكم استئناف   تجارية. |
# | Leur nombre, leurs sièges dans les régions et leur ressort sont fixés par décret. | يحدث بمرسوم عدد هذه المحاكم و مقارها بالجهات و دوائر اختصاصها. |
# | TITRE II : COMPOSITION ET ORGANISATION DES TRIBUNAUX DE COMMERCE ET DES COURS D'APPEL DE COMMERCE | القسم الثاني تكوين المحاكم التجارية و محاكم الاستئناف التجارية و تنظيمها |
# all is goood
# ---
#  ---
# length
# | French Text                                                  | Arabic Text                                                                 |
# |--------------------------------------------------------------|-----------------------------------------------------------------------------|
# ...

# %% [markdown]
# response = openai.ChatCompletion.create(
#   model = "gpt-3.5-turbo",
#   temperature = 0.1,
#   max_tokens = 1000,
#   messages = [
#     {"role": "system", "content": f"you are an assistant that takes a text in two languages and allign them in a table"},
#     {"role": "assistant", "content": f"give me text in two languages and I will give you complete sentences alignment"},
#     {"role": "user", "content": f"align the text into a table of french and english:\n\n {Text_fr}"}
#   ]
# )
#
#
#
#
# print(response['choices'][0]['message']['content'])

# %%
import open a
# Out:
#   File "<ipython-input-14-8ea10967e421>", line 5
#     -d '{
#        ^
# SyntaxError: unterminated string literal (detected at line 5)
